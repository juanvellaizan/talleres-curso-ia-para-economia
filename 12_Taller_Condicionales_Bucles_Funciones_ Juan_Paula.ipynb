# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/2_Programacion_en_Python/12_Taller_Condicionales_Bucles_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Taller Programación en Python: Condicionales, bucles y funciones**
# ---

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en parejas o grupos de 3**

# %% [markdown]
# **Nombres estudiantes:**
#
# -
# -
# -

# %% [markdown]
# **Forma de entrega:**
#
# - Nombrar el archivo de la siguiente forma: “Taller_Funciones_Apellidos.ipynb”.
# - Suba el Jupyter Notebook a su cuenta en Github y envíe el link en el siguiente Forms: https://forms.cloud.microsoft/r/xin7YSAtJe.
#
# **IMPORTANTE:** No se recibirán talleres en Google Colab, el notebook debe estar subido en Github.

# %% [markdown]
# **Plazo de entrega:**
#
# 13 de agosto de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# - Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.
# - **No modifiques** las celdas que ya traen los datos definidos, ni la última celda del notebook.
# - Usa **exactamente** los nombres de variables y funciones que pide cada enunciado: la verificación automática los busca por nombre.
# - Cuando el resultado no sea un número entero, redondéalo a 2 decimales con `round(valor, 2)`.
# - Cuando el enunciado pida un texto exacto, cópialo tal cual (respetando mayúsculas y tildes).
# - Al terminar, ejecuta la **última celda** del notebook: te dirá cuántos ejercicios tienes correctos y tu puntaje sobre 20. Puedes ejecutarla todas las veces que quieras mientras resuelves el taller.

# %% [markdown]
# **Contexto:**
#
# Trabajas en el equipo de *Estudios Económicos* de una entidad que hace seguimiento a la inflación, el empleo y los ingresos de los hogares colombianos. Tu tarea es automatizar los cálculos del informe trimestral: aumentos salariales, líneas de pobreza, impuestos, exportaciones, metas de ahorro y proyecciones de inversión.

# %% [markdown]
# ---
# ## **Nivel 1 — Condicionales**

# %% [markdown]
# ### **Ejercicio 1: Aumento Salarial por Inflación**
#
# El Gobierno define el aumento del salario mínimo según la inflación del año anterior:
#
# - Si la inflación es **mayor** al 10%, el aumento aprobado es del 12%.
# - Si la inflación está **entre 6% y 10%** (ambos incluidos), el aumento es del 8%.
# - Si la inflación es **menor** al 6%, el aumento es del 5%.
#
# Usando `if`, `elif` y `else`, guarda en una variable llamada `aumento` el porcentaje de aumento del salario mínimo que corresponde a una inflación de 8.4%.

# %%
inflacion_anual = 8.4

# %%
### TU CÓDIGO AQUÍ ###
inflacion_anual = 8.4

if inflacion_anual > 10:
    aumento = 12
elif inflacion_anual >= 6:
    aumento = 8
else:
    aumento = 5


print(f"El aumento salarial aprobado es del {aumento}%")
# Out:
# El aumento salarial aprobado es del 8%

# %% [markdown]
# ### **Ejercicio 2: Ingreso del Hogar en Salarios Mínimos**
#
# El salario mínimo mensual es de 1.423.500 pesos. Necesitas clasificar el ingreso de un hogar:
#
# 1. Calcula cuántos salarios mínimos representa el ingreso del hogar y guarda el resultado **redondeado a 2 decimales** en una variable llamada `n_salarios`.
# 2. Guarda en una variable llamada `clasificacion` uno de estos tres textos, exactamente como aparecen aquí:
#    - `"Menos de un salario mínimo"` si `n_salarios` es menos de 1 salario mínimo.
#    - `"Entre 1 y 2 salarios mínimos"` si `n_salarios` está entre 1 y 2 (incluyendo el 2).
#    - `"Más de 2 salarios mínimos"` si `n_salarios` supera los 2 salarios mínimos.

# %%
ingreso_hogar = 3450000
salario_minimo = 1423500

# %%
### TU CÓDIGO AQUÍ ###
ingreso_hogar = 3450000
salario_minimo = 1423500

n_salarios = round(ingreso_hogar / salario_minimo, 2)

if n_salarios < 1:
    clasificacion = "Menos de un salario mínimo"
elif n_salarios <= 2:
    clasificacion = "Entre 1 y 2 salarios mínimos"
else:
    clasificacion = "Más de 2 salarios mínimos"

print(f"Número de salarios mínimos: {n_salarios}")
print(f"Clasificación: {clasificacion}")

print(f"El hogar gana {n_salarios} salarios mínimos: {clasificacion}")
# Out:
# Número de salarios mínimos: 2.42
# Clasificación: Más de 2 salarios mínimos
# El hogar gana 2.42 salarios mínimos: Más de 2 salarios mínimos

# %% [markdown]
# ### **Ejercicio 3: Línea de Pobreza del DANE**
#
# El DANE define la línea de pobreza en 400.000 pesos mensuales **por persona** y la línea de pobreza extrema en 200.000 pesos por persona.
#
# 1. Calcula el ingreso mensual por persona del hogar y guárdalo en una variable llamada `ingreso_per_capita`.
# 2. Guarda en una variable llamada `situacion` uno de estos tres textos, exactamente como aparecen aquí:
#    - `"Pobreza extrema"` si el ingreso por persona es menor a 200.000.
#    - `"Pobreza"` si está entre 200.000 y 400.000 (incluyendo el 400.000).
#    - `"No está en pobreza"` si supera los 400.000.

# %%
ingreso_hogar_mensual = 1200000
personas_hogar = 4

# %%
### TU CÓDIGO AQUÍ ###
ingreso_per_capita = ingreso_hogar_mensual / personas_hogar

if ingreso_per_capita < 200000:
    situacion = "Pobreza extrema"
elif ingreso_per_capita <= 400000:
    situacion = "Pobreza"
else:
    situacion = "No está en pobreza"

print(f"Ingreso por persona: {ingreso_per_capita} pesos. Situación: {situacion}")
# Out:
# Ingreso por persona: 300000.0 pesos. Situación: Pobreza

# %% [markdown]
# ### **Ejercicio 4: ¿Le Conviene Exportar a la Empresa?**
#
# Una empresa evalúa si exporta un producto. Por cada unidad recibe el precio internacional, pero debe pagar el costo de exportación (fletes y trámites) y el costo de producción.
#
# 1. Calcula el margen que le queda por unidad y guárdalo en una variable llamada `margen_unitario`.
# 2. Guarda en una variable llamada `exportar` el resultado de evaluar, con el operador lógico `and`, estas dos condiciones a la vez: que el margen unitario sea mayor que cero **y** que el precio internacional supere el costo de producción. El resultado debe ser `True` o `False`.

# %%
costo_produccion = 50
precio_internacional = 70
costo_exportacion = 25

# %%
### TU CÓDIGO AQUÍ ###
margen_unitario = precio_internacional - costo_exportacion - costo_produccion

exportar = margen_unitario > 0 and precio_internacional > costo_produccion


print(f"Margen por unidad: {margen_unitario} USD. ¿Exportar? {exportar}")
# Out:
# Margen por unidad: -5 USD. ¿Exportar? False

# %% [markdown]
# ### **Ejercicio 5: Tramos del Impuesto de Renta**
#
# Un país cobra el impuesto de renta según el ingreso anual:
#
# - Menos de 2.000.000 → 0%
# - Entre 2.000.000 y 5.000.000 (ambos incluidos) → 10%
# - Más de 5.000.000 → 20%
#
# 1. Guarda en una variable llamada `tasa` la tarifa que aplica, **expresada en decimales** (`0`, `0.1` o `0.2`).
# 2. Guarda en una variable llamada `impuesto` el valor en pesos que debe pagar esa persona.

# %%
ingreso_anual = 4800000

# %%
### TU CÓDIGO AQUÍ ###
if ingreso_anual < 2000000:
    tasa = 0
elif ingreso_anual <= 5000000:
    tasa = 0.1
else:
    tasa = 0.2

impuesto = ingreso_anual * tasa

print(f"Tasa aplicada: {tasa}. Impuesto a pagar: {impuesto} pesos")
# Out:
# Tasa aplicada: 0.1. Impuesto a pagar: 480000.0 pesos

# %% [markdown]
# ### **Ejercicio 6: Conversor de Moneda con Diccionario**
#
# El diccionario `monedas` guarda, para cada código de moneda, una tupla con el nombre de la moneda y su tasa de cambio en pesos.
#
# Sin escribir un `if` por cada moneda, usa el operador `in` para verificar si el código está en el diccionario:
#
# - Si **está**, guarda el nombre de la moneda en `nombre_moneda` y el valor convertido en `valor_convertido` (los pesos divididos entre la tasa de cambio, **redondeado a 2 decimales**).
# - Si **no está**, guarda en `nombre_moneda` el texto `"Moneda desconocida"` y en `valor_convertido` el número `0`.

# %%
monedas = {
    "EUR": ("euros", 4670),
    "USD": ("dólares", 4025),
    "GBP": ("libras", 5428),
}

pesos = 2000000
codigo = "USD"

# %%
### TU CÓDIGO AQUÍ ###
if codigo in monedas:
    nombre_moneda, tasa_cambio = monedas[codigo]
    valor_convertido = round(pesos / tasa_cambio, 2)
else:
    nombre_moneda = "Moneda desconocida"
    valor_convertido = 0

print(f"Moneda: {nombre_moneda}. Valor convertido: {valor_convertido}")
# Out:
# Moneda: dólares. Valor convertido: 496.89

# %% [markdown]
# ---
# ## **Nivel 2 — Bucles y primeras funciones**

# %% [markdown]
# ### **Ejercicio 7: Ciudades con Mayor Número de Empresas**
#
# La lista `empresas_por_ciudad` tiene el número de empresas registradas en cada ciudad del país.
#
# Usa un ciclo `for` para contar cuántas ciudades tienen **más de 100** empresas registradas y guarda el resultado en una variable llamada `n_ciudades_grandes`. Recuerda crear el contador en `0` antes del ciclo.

# %%
empresas_por_ciudad = [120, 85, 340, 210, 95, 150]

# %%
### TU CÓDIGO AQUÍ ###
n_ciudades_grandes = 0

for empresas in empresas_por_ciudad:
    if empresas > 100:
        n_ciudades_grandes += 1

print(f"Número de ciudades con más de 100 empresas: {n_ciudades_grandes}")
# Out:
# Número de ciudades con más de 100 empresas: 4

# %% [markdown]
# ### **Ejercicio 8: Total y Promedio de Exportaciones**
#
# El diccionario `exportaciones` tiene las exportaciones de cada país en millones de USD.
#
# Usa un ciclo `for` sobre los **valores** del diccionario para:
#
# 1. Acumular la suma de todas las exportaciones en una variable llamada `total_exportado`.
# 2. Calcular el promedio y guardarlo en una variable llamada `promedio_exportaciones`, **redondeado a 2 decimales**.

# %%
exportaciones = {
    "Colombia": 1500,
    "México": 2300,
    "Chile": 1200,
    "Perú": 1800,
    "Ecuador": 900,
}

# %%
### TU CÓDIGO AQUÍ ###
total_exportado = 0

for valor in exportaciones.values():
    total_exportado += valor

promedio_exportaciones = round(total_exportado / len(exportaciones), 2)

print(f"Total exportado: {total_exportado} millones de USD")
print(f"Promedio por país: {promedio_exportaciones} millones de USD")
# Out:
# Total exportado: 7700 millones de USD
# Promedio por país: 1540.0 millones de USD

# %% [markdown]
# ### **Ejercicio 9: Escala de Retención en la Fuente**
#
# La tabla de retención en la fuente se organiza por topes de ingreso mensual: desde 2.000.000 hasta 10.000.000 de pesos, avanzando de 2.000.000 en 2.000.000.
#
# Usa `range()` para crear una lista llamada `rangos_ingreso` con esos topes. Ten cuidado con el límite: la lista **debe incluir** el tope de 10.000.000.

# %%
### TU CÓDIGO AQUÍ ###
rangos_ingreso = list(range(2000000, 10000001, 2000000))

print(rangos_ingreso)
# Out:
# [2000000, 4000000, 6000000, 8000000, 10000000]

# %% [markdown]
# ### **Ejercicio 10: Valor de la Canasta de Compras**
#
# Tienes tres listas paralelas: el nombre de cada producto, su precio por kilo y los kilos que compró un hogar.
#
# Usa un ciclo `for` con `range(len(...))` para recorrer las tres listas al mismo tiempo y:
#
# 1. Construye con `.append()` una lista llamada `valor_compra` con el valor pagado por cada producto (precio por kilo multiplicado por los kilos), en el mismo orden de la lista `productos`.
# 2. Guarda en una variable llamada `total_canasta` el valor total de la canasta.

# %%
productos = ["Café", "Azúcar", "Arroz", "Aceite"]
precios_kg = [5000, 3500, 4200, 12000]
kilos = [3, 2, 5, 1]

# %%
### TU CÓDIGO AQUÍ ###
valor_compra = []

for i in range(len(productos)):
    valor = precios_kg[i] * kilos[i]
    valor_compra.append(valor)

total_canasta = sum(valor_compra)


print(f"Valor por producto: {valor_compra}")
print(f"Total de la canasta: {total_canasta} pesos")
# Out:
# Valor por producto: [15000, 7000, 21000, 12000]
# Total de la canasta: 55000 pesos

# %% [markdown]
# ### **Ejercicio 11: Meta de Ahorro de un Hogar**
#
# Un hogar quiere ahorrar 5.000.000 de pesos para la cuota inicial de una vivienda y aporta 350.000 pesos cada mes.
#
# Usa un ciclo `while` para calcular:
#
# 1. Cuántos meses necesita hasta **alcanzar o superar** la meta, en una variable llamada `meses_ahorro`.
# 2. Cuánto dinero tiene ahorrado en ese momento, en una variable llamada `ahorro_final`.
#
# Recuerda crear las variables en `0` antes del ciclo y aumentarlas dentro de él.

# %%
### TU CÓDIGO AQUÍ ###
meta = 5000000
aporte_mensual = 350000

meses_ahorro = 0
ahorro_final = 0

while ahorro_final < meta:
    ahorro_final += aporte_mensual
    meses_ahorro += 1


print(f"La meta se alcanza en {meses_ahorro} meses con {ahorro_final} pesos ahorrados")
# Out:
# La meta se alcanza en 15 meses con 5250000 pesos ahorrados

# %% [markdown]
# ### **Ejercicio 12: Inversión con Interés Compuesto**
#
# Un inversionista pone 1.000 dólares en un fondo que rinde **5% mensual**. Los intereses se reinvierten, así que cada mes el saldo se multiplica por 1.05.
#
# Usa un ciclo `while` para calcular:
#
# 1. Cuántos meses pasan hasta que la inversión **supere** los 2.000 dólares, en una variable llamada `meses`.
# 2. El saldo alcanzado en ese momento, en una variable llamada `saldo_final`, **redondeado a 2 decimales**.

# %%
### TU CÓDIGO AQUÍ ###
saldo = 1000
meses = 0

while saldo <= 2000:
    saldo = saldo * 1.05
    meses += 1

saldo_final = round(saldo, 2)

print(f"La inversión supera los 2000 dólares en {meses} meses, con un saldo de {saldo_final} dólares")
# Out:
# La inversión supera los 2000 dólares en 15 meses, con un saldo de 2078.93 dólares

# %% [markdown]
# ### **Ejercicio 13: Amortización de un Crédito**
#
# Una empresa tiene una deuda de 5.000.000 de pesos y abona 600.000 pesos cada mes hasta pagarla por completo.
#
# Usa un ciclo `while` para calcular:
#
# 1. Cuántos pagos necesita hasta que la deuda deje de ser positiva, en una variable llamada `n_pagos`.
# 2. El saldo final de la deuda en una variable llamada `saldo_final_deuda`. Como el último pago puede ser mayor a lo que quedaba, usa `max()` para que el saldo nunca se muestre negativo.

# %%
### TU CÓDIGO AQUÍ ###
deuda = 5000000
pago_mensual = 600000

n_pagos = 0

while deuda > 0:
    deuda -= pago_mensual
    n_pagos += 1

saldo_final_deuda = max(0, deuda)

print(f"La deuda se paga en {n_pagos} pagos. Saldo final: {saldo_final_deuda} pesos")
# Out:
# La deuda se paga en 9 pagos. Saldo final: 0 pesos

# %% [markdown]
# ### **Ejercicio 14: Función para Clasificar la Inflación**
#
# Crea una función llamada `clasificar_inflacion` que reciba como parámetro la inflación anual y **retorne** uno de estos tres textos, exactamente como aparecen aquí:
#
# - `"Baja"` si la inflación es menor a 4.
# - `"Moderada"` si está entre 4 y 8 (ambos incluidos).
# - `"Alta"` si es mayor a 8.
#
# No olvides documentar la función con un docstring que explique qué hace, cuáles son sus parámetros y qué retorna.

# %%
### TU CÓDIGO AQUÍ ###
def clasificar_inflacion(inflacion):
    """
    Clasifica la inflación anual como baja, moderada o alta.

    Parámetro:
        inflacion (float): Inflación anual en porcentaje.

    Retorna:
        str: "Baja", "Moderada" o "Alta" según el nivel de inflación.
    """
    if inflacion < 4:
        return "Baja"
    elif inflacion <= 8:
        return "Moderada"
    else:
        return "Alta"

# %%
print(clasificar_inflacion(2.5))    # Una inflación baja
# Out:
# Baja

# %%
print(clasificar_inflacion(8))      # Justo en el límite superior del rango moderado
# Out:
# Moderada

# %%
print(clasificar_inflacion(12.7))   # Una inflación alta
# Out:
# Alta

# %% [markdown]
# ---
# ## **Nivel 3 — Funciones integradoras**

# %% [markdown]
# ### **Ejercicio 15: Función de Valor Futuro de una Inversión**
#
# Crea una función llamada `valor_futuro` que calcule cuánto vale una inversión al final de varios periodos con interés compuesto.
#
# - Recibe tres parámetros en este orden: `capital`, `periodos` y `tasa`.
# - El parámetro `tasa` debe tener un **valor por defecto de 0.05** (5%), para no tener que escribirlo cada vez.
# - Retorna el capital multiplicado por `(1 + tasa)` elevado a los periodos, **redondeado a 2 decimales**.
#
# Documenta la función con su docstring.

# %%
### TU CÓDIGO AQUÍ ###
def valor_futuro(capital, periodos, tasa=0.05):
    """
    Calcula el valor futuro de una inversión con interés compuesto.

    Parámetros:
        capital (float): Capital inicial.
        periodos (int): Número de periodos de inversión.
        tasa (float): Tasa de interés por periodo. Por defecto es 0.05 (5%).

    Retorna:
        float: Valor futuro de la inversión, redondeado a 2 decimales.
    """
    return round(capital * (1 + tasa) ** periodos, 2)

# %%
print(valor_futuro(1000, 2))            # Usa la tasa por defecto del 5%
# Out:
# 1102.5

# %%
print(valor_futuro(1000, 2, 0.1))       # Con una tasa del 10%
# Out:
# 1210.0

# %%
print(valor_futuro(capital=1500, periodos=4))   # Pasando los argumentos por palabra clave
# Out:
# 1823.26

# %% [markdown]
# ### **Ejercicio 16: Función para Calcular un Subsidio**
#
# El Gobierno entrega un subsidio mensual según el ingreso del hogar. Crea una función llamada `monto_subsidio` que reciba dos parámetros: el `ingreso` del hogar y `tiene_hijos`, que es un valor booleano (`True` o `False`).
#
# El subsidio base se calcula así:
#
# - Si el ingreso es menor a 1.000.000 → 300.000 pesos.
# - Si el ingreso está entre 1.000.000 y 2.000.000 (ambos incluidos) → 150.000 pesos.
# - Si el ingreso es mayor a 2.000.000 → 0 pesos.
#
# Además, si el hogar **tiene hijos menores** y le corresponde algún subsidio (es decir, el subsidio base es mayor que cero), se le suman 100.000 pesos adicionales.
#
# La función debe **retornar** el monto final del subsidio. No olvides el docstring.

# %%
### TU CÓDIGO AQUÍ ###
def monto_subsidio(ingreso, tiene_hijos):
    """
    Calcula el monto final del subsidio mensual según el ingreso del hogar
    y si tiene hijos menores.

    Parámetros:
        ingreso (float): Ingreso mensual del hogar.
        tiene_hijos (bool): Indica si el hogar tiene hijos menores.

    Retorna:
        int: Monto final del subsidio en pesos.
    """
    if ingreso < 1000000:
        subsidio = 300000
    elif ingreso <= 2000000:
        subsidio = 150000
    else:
        subsidio = 0

    if tiene_hijos and subsidio > 0:
        subsidio += 100000

    return subsidio

# %%
print(monto_subsidio(800000, True))     # Hogar de bajos ingresos con hijos
# Out:
# 400000

# %%
print(monto_subsidio(800000, False))    # El mismo hogar sin hijos
# Out:
# 300000

# %%
print(monto_subsidio(3000000, True))    # Hogar que no clasifica al subsidio
# Out:
# 0

# %% [markdown]
# ### **Ejercicio 17: Función que Cuenta los Meses sobre la Meta**
#
# El área comercial necesita saber en cuántos meses las ventas superaron la meta.
#
# Crea una función llamada `meses_sobre_meta` que reciba dos parámetros: una lista `ventas` con las ventas de cada mes y un número `meta`. La función debe usar un **ciclo `for` por dentro** para contar cuántos meses superaron **estrictamente** la meta, y **retornar** ese número.
#
# Documenta la función con su docstring.

# %%
### TU CÓDIGO AQUÍ ###
def meses_sobre_meta(ventas, meta):
    """
    Cuenta cuántos meses las ventas superaron estrictamente la meta.

    Parámetros:
        ventas (list): Lista con las ventas de cada mes.
        meta (float): Meta de ventas.

    Retorna:
        int: Número de meses que superaron la meta.
    """
    contador = 0

    for venta in ventas:
        if venta > meta:
            contador += 1

    return contador

# %%
print(meses_sobre_meta([1200, 950, 1400, 800, 1100], 1000))   # Ventas de 5 meses frente a una meta de 1000
# Out:
# 3

# %%
print(meses_sobre_meta([500, 600, 700], 1000))                # Un trimestre flojo
# Out:
# 0

# %%
print(meses_sobre_meta([1000, 1001], 1000))                   # Cuidado: la meta debe superarse, no igualarse
# Out:
# 1

# %% [markdown]
# ### **Ejercicio 18: Variación Porcentual de las Ventas**
#
# Para el informe mensual necesitas calcular cuánto crecieron las ventas frente al mes anterior. El problema es que algunos meses llegan con el valor anterior en cero o con texto en lugar de números.
#
# Crea una función llamada `variacion_porcentual` que reciba `valor_actual` y `valor_anterior`, y use `try` / `except` para:
#
# - Retornar la variación porcentual **redondeada a 2 decimales**, calculada como la diferencia entre los dos valores, dividida por el valor anterior y multiplicada por 100.
# - Si el valor anterior es cero, capturar el error `ZeroDivisionError` y retornar el texto: `"Error: el valor del mes anterior no puede ser cero."`
# - Si alguno de los valores no es numérico, capturar el error `TypeError` y retornar el texto: `"Error: los valores deben ser numéricos."`
#
# Documenta la función con su docstring.

# %%
### TU CÓDIGO AQUÍ ###
def variacion_porcentual(valor_actual, valor_anterior):
    """
    Calcula la variación porcentual de las ventas frente al mes anterior.

    Parámetros:
        valor_actual (float): Valor de ventas del mes actual.
        valor_anterior (float): Valor de ventas del mes anterior.

    Retorna:
        float o str: Variación porcentual redondeada a 2 decimales,
        o un mensaje de error si los valores no son válidos.
    """
    try:
        variacion = ((valor_actual - valor_anterior) / valor_anterior) * 100
        return round(variacion, 2)
    except ZeroDivisionError:
        return "Error: el valor del mes anterior no puede ser cero."
    except TypeError:
        return "Error: los valores deben ser numéricos."

# %%
print(variacion_porcentual(110, 100))         # Las ventas crecieron
# Out:
# 10.0

# %%
print(variacion_porcentual(95, 100))          # Las ventas cayeron
# Out:
# -5.0

# %%
print(variacion_porcentual(50, 0))            # El mes anterior no registró ventas
# Out:
# Error: el valor del mes anterior no puede ser cero.

# %%
print(variacion_porcentual(100, "sin dato"))  # El dato llegó como texto
# Out:
# Error: los valores deben ser numéricos.

# %% [markdown]
# ### **Ejercicio 19: Limpieza de la Encuesta de Ingresos**
#
# Los ingresos de la encuesta de hogares llegan como **texto** desde el formulario web, y algunos vienen con respuestas que no son números o incluso vacíos.
#
# Crea una función llamada `a_numero` que reciba un parámetro `valor` y use `try` / `except` para:
#
# - Retornar el valor convertido a número decimal con `float()`.
# - Si el texto no se puede convertir a número, capturar el error `ValueError` y retornar: `"Error: el valor no es numérico."`
# - Si el tipo de dato no admite la conversión (por ejemplo cuando llega vacío como `None`), capturar el error `TypeError` y retornar: `"Error: el tipo de dato no se puede convertir."`
#
# Documenta la función con su docstring.

# %%
### TU CÓDIGO AQUÍ ###
def a_numero(valor):
    """
    Convierte un valor a número decimal.

    Parámetro:
        valor: Valor que se desea convertir.

    Retorna:
        float o str: El valor convertido o un mensaje de error.
    """
    try:
        return float(valor)
    except ValueError:
        return "Error: el valor no es numérico."
    except TypeError:
        return "Error: el tipo de dato no se puede convertir."

# %%
print(a_numero("1500000"))      # Un ingreso válido
# Out:
# 1500000.0

# %%
print(a_numero("12.5"))         # Un número con decimales
# Out:
# 12.5

# %%
print(a_numero("no responde"))  # El encuestado no respondió
# Out:
# Error: el valor no es numérico.

# %%
print(a_numero(None))           # La casilla llegó vacía
# Out:
# Error: el tipo de dato no se puede convertir.

# %% [markdown]
# ### **Ejercicio 20: Consulta del PIB per Cápita**
#
# El diccionario `pib_percapita` guarda el PIB per cápita de algunos países en dólares, y la lista `paises_consulta` tiene los países que te pidieron consultar. Fíjate que no todos los países de la lista están en el diccionario.
#
# Este ejercicio integra los tres temas del taller:
#
# 1. Crea una función llamada `consultar_pib` que reciba el nombre de un país y use `try` / `except` para retornar su PIB per cápita. Si el país no está en el diccionario, debe capturar el error `KeyError` y retornar el texto `"Dato no disponible para "` seguido del nombre del país (por ejemplo: `"Dato no disponible para Bolivia"`). No olvides el docstring.
# 2. Usando un ciclo `for` sobre `paises_consulta` y `.append()`, construye una lista llamada `resultados_pib` con el resultado de llamar a tu función para cada país, en el mismo orden de la lista.

# %%
pib_percapita = {
    "Colombia": 6700,
    "Chile": 15300,
    "Perú": 7100,
    "México": 11500,
}

paises_consulta = ["Colombia", "Bolivia", "Chile"]

# %%
### TU CÓDIGO AQUÍ ###
def consultar_pib(pais):
    """
    Consulta el PIB per cápita de un país.

    Parámetro:
        pais (str): Nombre del país a consultar.

    Retorna:
        int o str: PIB per cápita o mensaje si no hay datos.
    """
    try:
        return pib_percapita[pais]
    except KeyError:
        return f"Dato no disponible para {pais}"


resultados_pib = []

for pais in paises_consulta:
    resultados_pib.append(consultar_pib(pais))

print(resultados_pib)
# Out:
# [6700, 'Dato no disponible para Bolivia', 15300]

# %%
print(consultar_pib("Chile"))     # Un país que sí está en el diccionario
# Out:
# 15300

# %%
print(consultar_pib("Bolivia"))   # Un país que no está en el diccionario
# Out:
# Dato no disponible para Bolivia

# %% [markdown]
# ---
#
# Ejecuta esta celda al finalizar todo el taller. Te mostrará cuántos ejercicios tienes correctos y tu puntaje. Si algún ejercicio aparece con ❌, revísalo y vuelve a ejecutar la celda.

# %%
import hashlib

_SAL = "extdo-macro-2026-II"


def _canon(x):
    if isinstance(x, bool):
        return repr(x)
    if isinstance(x, dict):
        return "D[" + ",".join(_canon(k) + ":" + _canon(v) for k, v in sorted(x.items(), key=str)) + "]"
    if isinstance(x, (list, tuple)):
        return "L[" + ",".join(_canon(i) for i in x) + "]"
    if isinstance(x, float):
        if x == int(x):
            return str(int(x))
        return repr(round(x, 2))
    return repr(x)


def _huella(n, valor):
    return hashlib.sha256((_SAL + "|" + str(n) + "|" + _canon(valor)).encode("utf-8")).hexdigest()[:16]


def verificar_taller():
    pruebas = [
        ( 1, "0ab675f43f183e3d", lambda: aumento),
        ( 2, "75e7a328ade6aa73", lambda: [n_salarios, clasificacion]),
        ( 3, "ea28574dcb3e5782", lambda: [ingreso_per_capita, situacion]),
        ( 4, "71e1be6e8c7d5f28", lambda: [margen_unitario, exportar]),
        ( 5, "72443d2a08c08ca5", lambda: [tasa, impuesto]),
        ( 6, "861358b241c07846", lambda: [nombre_moneda, valor_convertido]),
        ( 7, "0016ac9222ded042", lambda: n_ciudades_grandes),
        ( 8, "89d7af53f2e6b56e", lambda: [total_exportado, promedio_exportaciones]),
        ( 9, "7981ccb78dd1eecb", lambda: rangos_ingreso),
        (10, "eecdbaad2b00cbdb", lambda: [valor_compra, total_canasta]),
        (11, "d855aff5e95ff5b2", lambda: [meses_ahorro, ahorro_final]),
        (12, "69e1023ba96ae67a", lambda: [meses, saldo_final]),
        (13, "93c87106721d9220", lambda: [n_pagos, saldo_final_deuda]),
        (14, "10104e882bd0a604", lambda: [clasificar_inflacion(2.5), clasificar_inflacion(4), clasificar_inflacion(8), clasificar_inflacion(12.7), clasificar_inflacion(3.9), clasificar_inflacion(8.1)]),
        (15, "48608b77478c9045", lambda: [valor_futuro(1000, 2), valor_futuro(1000, 2, 0.1), valor_futuro(2000000, 6), valor_futuro(capital=1500, periodos=4), valor_futuro(750000, 3, 0.08)]),
        (16, "5b2530f607749844", lambda: [monto_subsidio(800000, True), monto_subsidio(800000, False), monto_subsidio(1500000, True), monto_subsidio(3000000, True), monto_subsidio(2000000, False), monto_subsidio(999999, True)]),
        (17, "463d5f171811fad5", lambda: [meses_sobre_meta([1200, 950, 1400, 800, 1100], 1000), meses_sobre_meta([500, 600, 700], 1000), meses_sobre_meta([1000, 1001], 1000), meses_sobre_meta([2400, 300, 2400, 300, 2400], 1500)]),
        (18, "8624ad024a2919c2", lambda: [variacion_porcentual(110, 100), variacion_porcentual(95, 100), variacion_porcentual(50, 0), variacion_porcentual(100, "sin dato"), variacion_porcentual(1350, 1200), variacion_porcentual(0, 800)]),
        (19, "c4966167d25dcab3", lambda: [a_numero("1500000"), a_numero("12.5"), a_numero("no responde"), a_numero(None), a_numero("980500"), a_numero("sin información")]),
        (20, "fed775493b7ca3ba", lambda: [consultar_pib("Chile"), consultar_pib("Bolivia"), consultar_pib("Perú"), consultar_pib("Uruguay"), resultados_pib]),
    ]

    resultados = {}
    for numero, esperado, obtener in pruebas:
        try:
            resultados[numero] = (_huella(numero, obtener()) == esperado)
        except Exception:
            resultados[numero] = False

    correctos = 0
    for numero in resultados:
        if resultados[numero]:
            correctos += 1
    total = len(pruebas)
    nota = round(correctos * 20 / total, 1)

    print("=" * 60)
    print("  VERIFICACIÓN AUTOMÁTICA DEL TALLER")
    print("=" * 60)

    fila = ""
    for numero, _esperado, _obtener in pruebas:
        icono = "✅" if resultados[numero] else "❌"
        fila += "  Ej %2d: %s " % (numero, icono)
        if numero % 5 == 0:
            print(fila)
            fila = ""
    if fila:
        print(fila)

    print("-" * 60)
    print("  RESULTADO: %d de %d ejercicios correctos" % (correctos, total))
    print("  PUNTAJE:   %s de 20 puntos" % nota)
    print("=" * 60)

    pendientes = []
    for numero, _esperado, _obtener in pruebas:
        if not resultados[numero]:
            pendientes.append(str(numero))

    if not pendientes:
        print("  🎉 ¡Felicidades! El informe de Estudios Económicos quedó impecable.")
    else:
        print("  Revisa estos ejercicios: " + ", ".join(pendientes))
        print("  Pista: verifica el nombre exacto de las variables y funciones, el")
        print("  redondeo a 2 decimales y que los mensajes de texto estén idénticos.")


verificar_taller()
# Out:
# ...
#   VERIFICACIÓN AUTOMÁTICA DEL TALLER
# ...
#   Ej  1: ✅   Ej  2: ✅   Ej  3: ✅   Ej  4: ✅   Ej  5: ✅
#   Ej  6: ✅   Ej  7: ✅   Ej  8: ✅   Ej  9: ✅   Ej 10: ✅
#   Ej 11: ✅   Ej 12: ✅   Ej 13: ✅   Ej 14: ✅   Ej 15: ✅
#   Ej 16: ✅   Ej 17: ✅   Ej 18: ✅   Ej 19: ✅   Ej 20: ✅
# ------------------------------------------------------------
#   RESULTADO: 20 de 20 ejercicios correctos
#   PUNTAJE:   20.0 de 20 puntos
# ...
#   🎉 ¡Felicidades! El informe de Estudios Económicos quedó impecable.
